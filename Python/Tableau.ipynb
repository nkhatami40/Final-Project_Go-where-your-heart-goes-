# %%
import pandas as pd
import numpy as np

# %%
data_heart = pd.read_csv('heart_disease_df.csv')

# %%
data_heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  heart_disease
# 0         2   2     3              0
# ...

# %%
data_heart['heart_disease'] = data_heart['heart_disease'].map({0: 'No', 1: 'Yes'})

# %%
data_heart['sex'] = data_heart['sex'].map({0: 'Female', 1: 'Male'})

# %%
data_heart['fbs'] = data_heart['fbs'].map({0: 'No', 1: 'Yes'})

# %%
data_heart['exang'] = data_heart['exang'].map({0: 'No', 1: 'Yes'})

# %%
data_heart['cp'] = data_heart['cp'].map({0: 'typical angina', 1: 'atypical angina', 2: 'non-anginal pain', 3: 'asymptomic'})

# %%
data_heart['restecg'] = data_heart['restecg'].map({0: 'normal', 1: 'ST-T wave abnormality', 2: 'probable or definite left ventricular hypertrophy'})

# %%
data_heart['slope'] = data_heart['slope'].map({0: 'downsloping', 1: 'flat', 2: 'upsloping'})

# %%
data_heart['thal'] = data_heart['thal'].map({0: 'null', 1: 'fixed defect', 2: 'normal blood flow', 3: 'reversible defect'})

# %%
data_heart
# Out:
#       age     sex               cp  trestbps  chol  fbs  \
# 0      52    Male   typical angina       125   212   No
# 1      53    Male   typical angina       140   203  Yes
# 2      70    Male   typical angina       145   174   No
# 3      61    Male   typical angina       148   203   No
# 4      62  Female   typical angina       138   294  Yes
# ...   ...     ...              ...       ...   ...  ...
# 1020   59    Male  atypical angina       140   221   No
# 1021   60    Male   typical angina       125   258   No
# 1022   47    Male   typical angina       110   275   No
# 1023   50  Female   typical angina       110   254   No
# 1024   54    Male   typical angina       120   188   No
#
#                     restecg  thalach exang  oldpeak        slope  ca  \
# 0     ST-T wave abnormality      168    No      1.0    upsloping   2
# 1                    normal      155   Yes      3.1  downsloping   0
# 2     ST-T wave abnormality      125   Yes      2.6  downsloping   0
# ...

# %%
data_heart.to_csv('heart_data_Tablaeu.csv', sep=',', index=False, encoding='utf-8')

# %%
data_heart['heart_disease'] = data_heart['heart_disease'].astype(str)

# %%
data_heart['sex'] = data_heart['sex'].astype(str)

# %%
data_heart['cp'] = data_heart['cp'].astype(str)

# %%
data_heart['fbs'] = data_heart['fbs'].astype(str)

# %%
data_heart['restecg'] = data_heart['restecg'].astype(str)

# %%
data_heart['exang'] = data_heart['exang'].astype(str)

# %%
data_heart['slope'] = data_heart['slope'].astype(str)

# %%
data_heart['thal'] = data_heart['thal'].astype(str)

# %%
data_heart.to_csv('heart_data_Tablaeu2.csv', sep=',', index=False, encoding='utf-8')
